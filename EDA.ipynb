# %%
import numpy as np
import nibabel as nib
from pathlib import Path
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
Path.ls = lambda x: [i for i in x.iterdir()]

# %%
PATH = Path("/home/shaun/Documents/acdc-seg/")

# %%
(PATH/"training/patient100").ls()
# Out:
# [PosixPath('/home/shaun/Documents/acdc-seg/training/patient100/Info.cfg'),
#  PosixPath('/home/shaun/Documents/acdc-seg/training/patient100/patient100_frame13.nii.gz'),
#  PosixPath('/home/shaun/Documents/acdc-seg/training/patient100/patient100_frame01.nii.gz'),
#  PosixPath('/home/shaun/Documents/acdc-seg/training/patient100/patient100_frame01_gt.nii.gz'),
#  PosixPath('/home/shaun/Documents/acdc-seg/training/patient100/patient100_4d.nii.gz'),
#  PosixPath('/home/shaun/Documents/acdc-seg/training/patient100/patient100_frame13_gt.nii.gz')]

# %%
def to_np(file_path):
    data = nib.load(file_path)
    return data.get_data()

# %%
patient = to_np("/home/shaun/Documents/acdc-seg/training/patient100/patient100_frame13.nii.gz")
# Out:
# (1.31579, 1.31579, 10.0)

# %%
patient_lbl =  to_np("/home/shaun/Documents/acdc-seg/training/patient100/patient100_frame13_gt.nii.gz")
# Out:
# (1.31579, 1.31579, 10.0)

# %%
patient.shape
# Out:
# (216, 304, 8)

# %%
plt.imshow(patient[:,:,2])

# %%
plt.imshow(patient_lbl[:,:,3])

# %%
patient_new = torch.from_numpy(np.reshape(patient,(17,1,174,208)))
