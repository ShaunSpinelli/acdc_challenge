# %%
import numpy as np
import nibabel as nib
from pathlib import Path
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
Path.ls = lambda x: [i for i in x.iterdir()]

# %%
PATH = Path("/home/shaun/personal/acdc_challenge/data")

# %%
! ls $PATH
# Out:
# images	labels	patient001.Info.cfg  training-raw

# %%
(PATH/"training-raw/patient100").ls()
# Out:
# [PosixPath('/home/shaun/personal/acdc_challenge/data/training-raw/patient100/Info.cfg'),
#  PosixPath('/home/shaun/personal/acdc_challenge/data/training-raw/patient100/patient100_frame01.nii.gz'),
#  PosixPath('/home/shaun/personal/acdc_challenge/data/training-raw/patient100/patient100_frame01_gt.nii.gz'),
#  PosixPath('/home/shaun/personal/acdc_challenge/data/training-raw/patient100/patient100_frame13.nii.gz'),
#  PosixPath('/home/shaun/personal/acdc_challenge/data/training-raw/patient100/patient100_frame13_gt.nii.gz'),
#  PosixPath('/home/shaun/personal/acdc_challenge/data/training-raw/patient100/patient100_4d.nii.gz')]

# %%
def to_np(file_path):
    data = nib.load(file_path)
    return data.get_data()

# %%
patient = to_np("/home/shaun/personal/acdc_challenge/data/training-raw/patient100/patient100_frame13.nii.gz")

# %%
patient_lbl =  to_np("/home/shaun/personal/acdc_challenge/data/training-raw/patient100/patient100_frame13.nii.gz")

# %%
x = patient.reshape((8, 304, 216))

# %%
plt.imshow(x[0])

# %%
plt.imshow(patient[:,:,2])

# %%
plt.imshow(patient_lbl[:,:,3])

# %%
patient_new = torch.from_numpy(np.reshape(patient,(17,1,174,208)))

# %%
x =patient_lbl[:,:,3]

# %%
x.shape
# Out:
# (216, 304)

# %%
x = np.load("/home/shaun/personal/acdc_challenge/data/images/patient051_frame01.nii-1.npy")
